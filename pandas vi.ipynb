# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','d','e'])
print(df)
df.plot.area()
# Out:
#           a         b         d         e
# 0  0.158821  0.313033  0.868259  0.081596
# 1  0.626997  0.136603  0.879010  0.082578
# 2  0.865309  0.261230  0.886157  0.364384
# 3  0.213775  0.393072  0.126897  0.569875
# 4  0.058622  0.975077  0.665958  0.433935
# 5  0.705153  0.696567  0.674045  0.222632
# 6  0.544447  0.899451  0.648895  0.882757
# 7  0.440171  0.728143  0.897301  0.559816
# 8  0.654594  0.140000  0.321450  0.937156
# 9  0.067793  0.932209  0.450195  0.028638

# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.rand(2,4),columns=['a','b','d','e'])
print(df)
df.plot.box()
# Out:
#             a         b         d         e
# 0    0.937678  0.931024  0.195218  0.661996
# 1    0.460150  0.071066  0.086722  0.676371
# 2    0.730115  0.335115  0.924290  0.064818
# 3    0.058447  0.420305  0.045252  0.240664
# 4    0.716745  0.508856  0.808657  0.507178
# 5    0.153108  0.457265  0.128230  0.042217
# 6    0.948445  0.587292  0.014316  0.745686
# 7    0.441310  0.894732  0.073390  0.303273
# 8    0.412542  0.935157  0.259895  0.759219
# 9    0.028213  0.076845  0.871780  0.075038
# 10   0.121527  0.003488  0.960256  0.084663
# 11   0.410561  0.786535  0.890238  0.429952
# 12   0.988808  0.179012  0.437122  0.614780
# 13   0.615632  0.592140  0.127316  0.001603
# 14   0.828135  0.556192  0.744104  0.064831
# 15   0.087600  0.409225  0.960594  0.883209
# 16   0.768715  0.723535  0.627174  0.069339
# 17   0.609792  0.639571  0.833422  0.881268
# 18   0.507994  0.866413  0.443699  0.305456
# 19   0.416348  0.273551  0.550211  0.492777
# ...

# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(np.random.rand(100,4),columns=['a','b','d','e'])
print(df)
df.plot.scatter(x='a',y='b')
# Out:
#            a         b         d         e
# 0   0.812045  0.719598  0.443248  0.501085
# 1   0.823092  0.647457  0.304398  0.387237
# 2   0.449490  0.149996  0.390136  0.227559
# 3   0.075581  0.018517  0.863173  0.046276
# 4   0.234923  0.386656  0.220580  0.556763
# 5   0.768724  0.370351  0.451977  0.169926
# 6   0.040183  0.088195  0.399823  0.721235
# 7   0.733651  0.252628  0.998115  0.408643
# 8   0.822512  0.557125  0.173334  0.459354
# 9   0.360382  0.954331  0.747379  0.767549
# 10  0.425664  0.274072  0.118834  0.321127
# 11  0.573579  0.522230  0.993117  0.251549
# 12  0.387519  0.134704  0.233993  0.592243
# 13  0.811575  0.152044  0.890899  0.642392
# 14  0.147707  0.877330  0.868552  0.812787
# 15  0.947977  0.994720  0.716528  0.625830
# 16  0.458741  0.535338  0.738392  0.630853
# 17  0.893884  0.730562  0.544875  0.915016
# 18  0.193132  0.071118  0.103935  0.655293
# 19  0.769234  0.268625  0.629116  0.399891
# 20  0.713487  0.982746  0.848710  0.726833
# ...

# %%
import pandas as pd 
import numpy as np
df=pd.DataFrame(3*np.random.rand(2,4),columns=['"x"])
print(df)
df.plot.pie(subplots=true)
# Out:
#   File "<ipython-input-17-1e52d37e9bcc>", line 3
#     df=pd.DataFrame(3*np.random.rand(2,4),columns=['"x"])
#                                                          ^
# SyntaxError: EOL while scanning string literal
